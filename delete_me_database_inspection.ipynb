# %%
#################################################
# Dependencies
#################################################
import numpy as np

from flask import Flask, render_template, jsonify, redirect
from flask_cors import CORS

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.ext.declarative import declarative_base #classes into tables
from sqlalchemy.orm import Session, sessionmaker
from sqlalchemy import create_engine, func, inspect, Column, Integer, String

import psycopg2
import os

from data.databaseEngineering import write_databases
from processing.makeGeojson import choropleth_geojson, shootings_geoJSON

#################################################
# Write Databases
# Do only first time when setting up herokuapp, otherwise, leave commented out
#################################################
# write_databases()

#################################################
# Engine Setup
#################################################
engine = create_engine(os.environ.get('DATABASE_URL', '') or 'postgres://lqehqdnexeuwdi:e299f2b76843b838b81976e7cb183859f28b1cd99e6aa417fdce1340ce00fece@ec2-54-243-210-70.compute-1.amazonaws.com:5432/dbenqc5p6hbe3e')
# engine = create_engine('sqlite:///data/data.sqlite', convert_unicode=True, echo=False)
# engine = create_engine('postgresql://nupur_mathur:1BPdfWvnTSvMGDrPp48u5pQF0@localhost/crime_data')

#################################################
# Save reference to each table in database
#################################################
Base = declarative_base()
Base.metadata.reflect(engine)

# State Data
class Vcr(Base):
    __table__ = Base.metadata.tables['vcr']

class Violent_Crime(Base):
    __table__ = Base.metadata.tables['violent_crime']

class Unemployment(Base):
    __table__ = Base.metadata.tables['unemployment']

class Population(Base):
    __table__ = Base.metadata.tables['population']

class Murder(Base):
    __table__ = Base.metadata.tables['murder']

class Median_Household_Income_Stderr(Base):
    __table__ = Base.metadata.tables['median_household_income_stderr']

class Median_Household_Income(Base):
    __table__ = Base.metadata.tables['median_household_income']

# State outline
class State_Coordinates(Base):
    __table__ = Base.metadata.tables['state_coordinates']

# Point Data
class School_Shootings(Base):
    __table__ = Base.metadata.tables['school_shootings']

# Annual Data
class Snap(Base):
    __table__ = Base.metadata.tables['snap']

class Foreclosure(Base):
    __table__ = Base.metadata.tables['foreclosure']

#################################################
# Session Setup
#################################################
session = Session(bind=engine)

#################################################
# Flask Setup
#################################################
app = Flask(__name__)
CORS(app)

# %%
inspector = inspect(engine)

# %%
inspector = inspect(engine)
for table_name in inspector.get_table_names():
    print("**", table_name, "**" "\n--------\n--------\n")
    for column in inspector.get_columns(table_name):
        print("Column: %s" % column['name'], column['type'])
    print("\n\n")
# Out:
# ** vcr **
# --------
# --------
#
# Column: index BIGINT
# Column: state TEXT
# Column: 1990 DOUBLE PRECISION
# Column: 1991 DOUBLE PRECISION
# Column: 1992 DOUBLE PRECISION
# Column: 1993 DOUBLE PRECISION
# Column: 1994 DOUBLE PRECISION
# Column: 1995 DOUBLE PRECISION
# Column: 1996 DOUBLE PRECISION
# Column: 1997 DOUBLE PRECISION
# Column: 1998 DOUBLE PRECISION
# Column: 1999 DOUBLE PRECISION
# Column: 2000 DOUBLE PRECISION
# Column: 2001 DOUBLE PRECISION
# Column: 2002 DOUBLE PRECISION
# Column: 2003 DOUBLE PRECISION
# Column: 2004 DOUBLE PRECISION
# Column: 2005 DOUBLE PRECISION
# Column: 2006 DOUBLE PRECISION
# Column: 2007 DOUBLE PRECISION
# Column: 2008 DOUBLE PRECISION
# Column: 2009 DOUBLE PRECISION
# Column: 2010 DOUBLE PRECISION
# Column: 2011 DOUBLE PRECISION
# Column: 2012 DOUBLE PRECISION
# Column: 2013 DOUBLE PRECISION
# Column: 2014 DOUBLE PRECISION
# Column: stateId TEXT
#
#
#
# ** violent_crime **
# --------
# --------
#
# Column: state TEXT
# Column: 1990 BIGINT
# Column: 1991 BIGINT
# Column: 1992 BIGINT
# Column: 1993 BIGINT
# Column: 1994 BIGINT
# Column: 1995 BIGINT
# Column: 1996 BIGINT
# Column: 1997 BIGINT
# Column: 1998 BIGINT
# Column: 1999 BIGINT
# Column: 2000 BIGINT
# Column: 2001 BIGINT
# Column: 2002 BIGINT
# Column: 2003 BIGINT
# Column: 2004 BIGINT
# Column: 2005 BIGINT
# Column: 2006 BIGINT
# Column: 2007 BIGINT
# Column: 2008 BIGINT
# Column: 2009 BIGINT
# Column: 2010 BIGINT
# Column: 2011 BIGINT
# Column: 2012 BIGINT
# Column: 2013 BIGINT
# Column: 2014 BIGINT
# Column: stateId TEXT
#
#
#
# ** murder **
# --------
# --------
#
# Column: state TEXT
# Column: 1990 BIGINT
# Column: 1991 BIGINT
# Column: 1992 BIGINT
# Column: 1993 BIGINT
# Column: 1994 BIGINT
# Column: 1995 BIGINT
# Column: 1996 BIGINT
# Column: 1997 BIGINT
# Column: 1998 BIGINT
# Column: 1999 BIGINT
# Column: 2000 BIGINT
# Column: 2001 BIGINT
# Column: 2002 BIGINT
# Column: 2003 BIGINT
# Column: 2004 BIGINT
# Column: 2005 BIGINT
# Column: 2006 BIGINT
# Column: 2007 BIGINT
# Column: 2008 BIGINT
# Column: 2009 BIGINT
# Column: 2010 BIGINT
# Column: 2011 BIGINT
# Column: 2012 BIGINT
# Column: 2013 BIGINT
# Column: 2014 BIGINT
# Column: stateId TEXT
#
#
#
# ** unemployment **
# --------
# --------
#
# Column: state TEXT
# Column: 1990 DOUBLE PRECISION
# Column: 1991 DOUBLE PRECISION
# Column: 1992 DOUBLE PRECISION
# Column: 1993 DOUBLE PRECISION
# Column: 1994 DOUBLE PRECISION
# Column: 1995 DOUBLE PRECISION
# Column: 1996 DOUBLE PRECISION
# Column: 1997 DOUBLE PRECISION
# Column: 1998 DOUBLE PRECISION
# Column: 1999 DOUBLE PRECISION
# Column: 2000 DOUBLE PRECISION
# Column: 2001 DOUBLE PRECISION
# Column: 2002 DOUBLE PRECISION
# Column: 2003 DOUBLE PRECISION
# Column: 2004 DOUBLE PRECISION
# Column: 2005 DOUBLE PRECISION
# Column: 2006 DOUBLE PRECISION
# Column: 2007 DOUBLE PRECISION
# Column: 2008 DOUBLE PRECISION
# Column: 2009 DOUBLE PRECISION
# Column: 2010 DOUBLE PRECISION
# Column: 2011 DOUBLE PRECISION
# Column: 2012 DOUBLE PRECISION
# Column: 2013 DOUBLE PRECISION
# Column: 2014 DOUBLE PRECISION
# Column: 2015 DOUBLE PRECISION
# Column: stateId TEXT
#
#
#
# ** population **
# --------
# --------
#
# Column: state TEXT
# Column: 1990 BIGINT
# Column: 1991 BIGINT
# Column: 1992 BIGINT
# Column: 1993 BIGINT
# Column: 1994 BIGINT
# Column: 1995 BIGINT
# Column: 1996 BIGINT
# Column: 1997 BIGINT
# Column: 1998 BIGINT
# Column: 1999 BIGINT
# Column: 2000 BIGINT
# Column: 2001 BIGINT
# Column: 2002 BIGINT
# Column: 2003 BIGINT
# Column: 2004 BIGINT
# Column: 2005 BIGINT
# Column: 2006 BIGINT
# Column: 2007 BIGINT
# Column: 2008 BIGINT
# Column: 2009 BIGINT
# Column: 2010 BIGINT
# Column: 2011 BIGINT
# Column: 2012 BIGINT
# Column: 2013 BIGINT
# Column: 2014 BIGINT
# Column: 2015 BIGINT
# Column: 2016 BIGINT
# Column: 2017 BIGINT
# Column: stateId TEXT
#
#
#
# ** median_household_income **
# --------
# --------
#
# Column: state TEXT
# Column: 1990 BIGINT
# Column: 1991 BIGINT
# Column: 1992 BIGINT
# Column: 1993 BIGINT
# Column: 1994 BIGINT
# Column: 1995 BIGINT
# Column: 1996 BIGINT
# Column: 1997 BIGINT
# Column: 1998 BIGINT
# Column: 1999 BIGINT
# Column: 2000 BIGINT
# Column: 2001 BIGINT
# Column: 2002 BIGINT
# Column: 2003 BIGINT
# Column: 2004 BIGINT
# Column: 2005 BIGINT
# Column: 2006 BIGINT
# Column: 2007 BIGINT
# Column: 2008 BIGINT
# Column: 2009 BIGINT
# Column: 2010 BIGINT
# Column: 2011 BIGINT
# Column: 2012 BIGINT
# Column: 2013 BIGINT
# Column: 2014 BIGINT
# Column: 2015 BIGINT
# Column: 2016 BIGINT
# Column: stateId TEXT
#
#
#
# ** median_household_income_stderr **
# --------
# --------
#
# Column: state TEXT
# Column: 1990 BIGINT
# Column: 1991 BIGINT
# Column: 1992 BIGINT
# Column: 1993 BIGINT
# Column: 1994 BIGINT
# Column: 1995 BIGINT
# Column: 1996 BIGINT
# Column: 1997 BIGINT
# Column: 1998 BIGINT
# Column: 1999 BIGINT
# Column: 2000 BIGINT
# Column: 2001 BIGINT
# Column: 2002 BIGINT
# Column: 2003 BIGINT
# Column: 2004 BIGINT
# Column: 2005 BIGINT
# Column: 2006 BIGINT
# Column: 2007 BIGINT
# Column: 2008 BIGINT
# Column: 2009 BIGINT
# Column: 2010 BIGINT
# Column: 2011 BIGINT
# Column: 2012 BIGINT
# Column: 2013 BIGINT
# Column: 2014 BIGINT
# Column: 2015 BIGINT
# Column: 2016 BIGINT
# Column: stateId TEXT
#
#
#
# ** state_coordinates **
# --------
# --------
#
# Column: index BIGINT
# Column: coordType TEXT
# Column: coordinates TEXT
# Column: state TEXT
# Column: stateId BIGINT
#
#
#
# ** school_shootings **
# --------
# --------
#
# Column: index BIGINT
# Column: Date TEXT
# Column: City TEXT
# Column: State TEXT
# Column: Fatalities BIGINT
# Column: Year BIGINT
# Column: Latitude DOUBLE PRECISION
# Column: Longitude DOUBLE PRECISION
#
#
#
# ** foreclosure **
# --------
# --------
#
# Column: index BIGINT
# Column: year BIGINT
# Column: foreclosure_filings TEXT
# Column: completed_foreclosures TEXT
# Column: home_repos TEXT
#
#
#
# ** snap **
# --------
# --------
#
# Column: index BIGINT
# Column: year BIGINT
# Column: average_participation DOUBLE PRECISION
# Column: average_benefit_per_person DOUBLE PRECISION
# Column: total_benefits DOUBLE PRECISION
# Column: all_other_costs DOUBLE PRECISION
# Column: total_costs DOUBLE PRECISION
