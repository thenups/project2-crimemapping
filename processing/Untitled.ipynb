# %%
# Dependencies
import tweepy
import json
import numpy as np
import time

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = 'ibYsFmAdHS8fhnupeA3opTRHN'
consumer_secret = 'cSfliluzlYkSJ8EPJEOvQA5kKG9BE6MG1ddF8kHAyNc5ZJ6601'
access_token = '943311356534472704-3tToKzZ2RMDtNOo4frlY6IEAg6iWGL1'
access_token_secret = '42jS6EeOwV5ZaWde0LwxpL4dPyozVt5rv3URu7ZlP9m17'

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search Term
# search_term = input("what term do you want to search for? ")
search_term = 'school shooting'

# %%
# Search for 5 popular tweets
# public_tweets = api.search(search_term, count=5, result_type='popular')
# Search for 5 recent tweets
public_tweets = api.search(search_term, count=5, result_type='recent')

# %%
public_tweets
# Out:
# {'search_metadata': {'completed_in': 0.024,
#   'count': 5,
#   'max_id': 979064968782974976,
#   'max_id_str': '979064968782974976',
#   'next_results': '?max_id=979064959693828095&q=school%20shooting&count=5&include_entities=1&result_type=recent',
#   'query': 'school+shooting',
#   'refresh_url': '?since_id=979064968782974976&q=school%20shooting&result_type=recent&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 18:37:33 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 772958490356617216,
#       'id_str': '772958490356617216',
#       'indices': [3, 18],
#       'name': 'March For Our Lives 🇺🇸✊💙',
#       'screen_name': 'DisavowTrump16'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979064968782974976,
#    'id_str': '979064968782974976',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 54629,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 24 20:28:00 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/977643214420217858',
#        'indices': [117, 140],
#        'url': 'https://t.co/6qOT87Tp87'}],
#      'user_mentions': []},
#     'favorite_count': 91230,
#     'favorited': False,
#     'geo': None,
#     'id': 977643214420217858,
#     'id_str': '977643214420217858',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 54629,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Emma Gonzalez has been through so much from a school shooting to being demonized by the alt-right and yet she conti… https://t.co/6qOT87Tp87',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Sep 06 00:43:59 +0000 2016',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'We must fight every single day against the hatred and bigotry of the Trump Administration for our shared values of justice and equality. #LoveTrumpsHate #RESIST',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 3439,
#      'follow_request_sent': False,
#      'followers_count': 17727,
#      'following': False,
#      'friends_count': 11216,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 772958490356617216,
#      'id_str': '772958490356617216',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 172,
#      'location': '',
#      'name': 'March For Our Lives 🇺🇸✊💙',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/772958490356617216/1520394671',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/977555566607454215/Y3P_thM6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/977555566607454215/Y3P_thM6_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'DisavowTrump16',
#      'statuses_count': 7918,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @DisavowTrump16: Emma Gonzalez has been through so much from a school shooting to being demonized by the alt-right and yet she continues…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Apr 17 22:50:46 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'single gay Christian unicorn. Stuck in middle U.S.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1781,
#     'follow_request_sent': False,
#     'followers_count': 27,
#     'following': False,
#     'friends_count': 87,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 283738367,
#     'id_str': '283738367',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': 'oklahoma city, ok',
#     'name': 'outlandish',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/283738367/1441665043',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/836982215959535616/abEAdN9w_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836982215959535616/abEAdN9w_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'mydogfinn',
#     'statuses_count': 1316,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 18:37:32 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979064965322760193',
#       'indices': [116, 139],
#       'url': 'https://t.co/eMKxnHSvOn'}],
#     'user_mentions': [{'id': 3377353523,
#       'id_str': '3377353523',
#       'indices': [0, 11],
#       'name': 'Rodrigo Brito',
#       'screen_name': 'GaianBrito'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979064965322760193,
#    'id_str': '979064965322760193',
#    'in_reply_to_screen_name': 'GaianBrito',
#    'in_reply_to_status_id': 978984452872392705,
#    'in_reply_to_status_id_str': '978984452872392705',
#    'in_reply_to_user_id': 3377353523,
#    'in_reply_to_user_id_str': '3377353523',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': '@GaianBrito I agree 100% but legacy media like CNN absolutely does not do triple checking. David Hogg himself said… https://t.co/eMKxnHSvOn',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Apr 29 13:46:33 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '🇺🇸Firearms & Tactics Expert, Instructor, Gun Smith/Machinist  & Journalist. Analyst In Terrorism, Gun Politics, Myths, BLM, & Mass Shootings',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'lasetersgunworks.com',
#         'expanded_url': 'http://lasetersgunworks.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/y0WwQPKCuF'}]}},
#     'favourites_count': 468,
#     'follow_request_sent': False,
#     'followers_count': 3192,
#     'following': False,
#     'friends_count': 4302,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 3221492008,
#     'id_str': '3221492008',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 12,
#     'location': '',
#     'name': 'Brian Woods',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3221492008/1499425545',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/593412360934707200/88anc55D_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/593412360934707200/88anc55D_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'WORWoods',
#     'statuses_count': 7425,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/y0WwQPKCuF',
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 18:37:32 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 14247236,
#       'id_str': '14247236',
#       'indices': [3, 10],
#       'name': 'Scott Dworkin',
#       'screen_name': 'funder'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979064964806860800,
#    'id_str': '979064964806860800',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 556,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 28 14:42:46 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/979005884947927040',
#        'indices': [117, 140],
#        'url': 'https://t.co/HlkVebdgMd'}],
#      'user_mentions': []},
#     'favorite_count': 645,
#     'favorited': False,
#     'geo': None,
#     'id': 979005884947927040,
#     'id_str': '979005884947927040',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 556,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'These pro-gun Trump supporters defaced a Parkland Memorial, because that’s what pro-gun Trump supporters do when th… https://t.co/HlkVebdgMd',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Mar 28 21:38:52 +0000 2008',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Co-Founder @TheDemCoalition. Host of The #DworkinReport Podcast. #AMJoy on MSNBC Contributor. I help lead #TheResistance. I helped uncover #TrumpRussia scandal.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'DemocraticCoalition.org',
#          'expanded_url': 'http://DemocraticCoalition.org',
#          'indices': [0, 23],
#          'url': 'https://t.co/VhWKRFMpPL'}]}},
#      'favourites_count': 75671,
#      'follow_request_sent': False,
#      'followers_count': 319944,
#      'following': False,
#      'friends_count': 46456,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 14247236,
#      'id_str': '14247236',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 3202,
#      'location': '',
#      'name': 'Scott Dworkin',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14247236/1517267836',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/843990001532764160/yjMRQs74_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/843990001532764160/yjMRQs74_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'funder',
#      'statuses_count': 160946,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/VhWKRFMpPL',
#      'utc_offset': -14400,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @funder: These pro-gun Trump supporters defaced a Parkland Memorial, because that’s what pro-gun Trump supporters do when they get waste…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Mar 11 01:11:29 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "RTs don't imply endorsement. Likes may indicate a notable comment, whether or not I agree.\n\nIf you can't tolerate civil disagreement don't tweet.",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 77622,
#     'follow_request_sent': False,
#     'followers_count': 500,
#     'following': False,
#     'friends_count': 1330,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2382931142,
#     'id_str': '2382931142',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 18,
#     'location': 'Planet Earth',
#     'name': 'Unsocial Medium',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/748176335114280960/3_V5sm8o_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/748176335114280960/3_V5sm8o_normal.jpg',
#     'profile_link_color': '94D487',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'StillUnsocial',
#     'statuses_count': 32858,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 18:37:32 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 772958490356617216,
#       'id_str': '772958490356617216',
#       'indices': [3, 18],
#       'name': 'March For Our Lives 🇺🇸✊💙',
#       'screen_name': 'DisavowTrump16'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979064964567662599,
#    'id_str': '979064964567662599',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 54629,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 24 20:28:00 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/977643214420217858',
#        'indices': [117, 140],
#        'url': 'https://t.co/6qOT87Tp87'}],
#      'user_mentions': []},
#     'favorite_count': 91230,
#     'favorited': False,
#     'geo': None,
#     'id': 977643214420217858,
#     'id_str': '977643214420217858',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 54629,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Emma Gonzalez has been through so much from a school shooting to being demonized by the alt-right and yet she conti… https://t.co/6qOT87Tp87',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Sep 06 00:43:59 +0000 2016',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'We must fight every single day against the hatred and bigotry of the Trump Administration for our shared values of justice and equality. #LoveTrumpsHate #RESIST',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 3439,
#      'follow_request_sent': False,
#      'followers_count': 17727,
#      'following': False,
#      'friends_count': 11216,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 772958490356617216,
#      'id_str': '772958490356617216',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 172,
#      'location': '',
#      'name': 'March For Our Lives 🇺🇸✊💙',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/772958490356617216/1520394671',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/977555566607454215/Y3P_thM6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/977555566607454215/Y3P_thM6_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'DisavowTrump16',
#      'statuses_count': 7918,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @DisavowTrump16: Emma Gonzalez has been through so much from a school shooting to being demonized by the alt-right and yet she continues…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jul 27 21:54:27 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'photographer, artist, urban adventurer',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'flickr.com/photos/digiart…',
#         'expanded_url': 'http://www.flickr.com/photos/digiart2001/',
#         'indices': [0, 23],
#         'url': 'https://t.co/pBXiqVFrtS'}]}},
#     'favourites_count': 728,
#     'follow_request_sent': False,
#     'followers_count': 159,
#     'following': False,
#     'friends_count': 367,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 60721831,
#     'id_str': '60721831',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 7,
#     'location': 'New York City',
#     'name': 'Jason Kuffer',
#     'notifications': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000764310059/c052954f7792919f290a771a6e7dd252_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000764310059/c052954f7792919f290a771a6e7dd252_normal.jpeg',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'jasonkuffer',
#     'statuses_count': 2678,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/pBXiqVFrtS',
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 18:37:31 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 232402717,
#       'id_str': '232402717',
#       'indices': [3, 14],
#       'name': 'Missing 44 🌊',
#       'screen_name': 'SheilaInCT'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979064959693828096,
#    'id_str': '979064959693828096',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 616,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Mar 27 21:29:40 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/978745896916615168',
#        'indices': [117, 140],
#        'url': 'https://t.co/EFE8prgb5T'}],
#      'user_mentions': []},
#     'favorite_count': 1988,
#     'favorited': False,
#     'geo': None,
#     'id': 978745896916615168,
#     'id_str': '978745896916615168',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 616,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '"No amount of kindness or compassion alone would have changed the person that Nikolas Cruz is and was, or the horre… https://t.co/EFE8prgb5T',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Dec 31 02:00:48 +0000 2010',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Proud mama. I swear a lot. #94Percent',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 20790,
#      'follow_request_sent': False,
#      'followers_count': 2338,
#      'following': False,
#      'friends_count': 2838,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 232402717,
#      'id_str': '232402717',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 70,
#      'location': 'Connecticut, USA',
#      'name': 'Missing 44 🌊',
#      'notifications': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/581774232/ra2igp8h2d6mzymvzj51.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/581774232/ra2igp8h2d6mzymvzj51.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/232402717/1515692364',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/964682030742196225/Y76lnuNN_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964682030742196225/Y76lnuNN_normal.jpg',
#      'profile_link_color': '990099',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'SheilaInCT',
#      'statuses_count': 51119,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -14400,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @SheilaInCT: "No amount of kindness or compassion alone would have changed the person that Nikolas Cruz is and was, or the horrendous ac…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jan 27 13:41:58 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 4485,
#     'follow_request_sent': False,
#     'followers_count': 54,
#     'following': False,
#     'friends_count': 260,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 824975738826682368,
#     'id_str': '824975738826682368',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Colorado, USA',
#     'name': 'Wendy Webb',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/824975738826682368/1521945811',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/891454571842764801/f-RDMJ28_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/891454571842764801/f-RDMJ28_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'dubldub23',
#     'statuses_count': 1501,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}}]}

# %%
# View Search Object
# print(public_tweets)

compound_list = []
positive_list = []
negative_list = []
neutral_list = []
tweet_id = []
tweet_text = []

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    # Utilize JSON dumps to generate a pretty-printed json
    # print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    tweet_id.append(tweet['id'])
    tweet_text.append(tweet["text"])

    # Run Vader Analysis on each tweet
    compound = analyzer.polarity_scores(tweet['text'])["compound"]
    pos = analyzer.polarity_scores(tweet['text'])["pos"]
    neu = analyzer.polarity_scores(tweet['text'])["neu"]
    neg = analyzer.polarity_scores(tweet['text'])["neg"]

    # Add each value to the appropriate array
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)

# %%
tweet_id
# Out:
# [979064968782974976,
#  979064965322760193,
#  979064964806860800,
#  979064964567662599,
#  979064959693828096]

# %%
<blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">I can&#39;t wait until Trump claims illegitimacy of his approval numbers. <a href="https://t.co/PRabgEfpBs">https://t.co/PRabgEfpBs</a></p>&mdash; Kartik Venkatraman (@KartikRishabh) <a href="https://twitter.com/KartikRishabh/status/807661318421385216?ref_src=twsrc%5Etfw">December 10, 2016</a></blockquote>
<script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
