# %% [markdown]
# # Investigating Correlation: Economic Factors:

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import numpy as np
from scipy.stats.stats import pearsonr

# %% [markdown]
# ### Import population data and create dataframe

# %%
filepath = '../../raw/economic_stats/population_by_state_by_year.csv'
csv = pd.read_csv(filepath)
population_df = pd.DataFrame(csv)

# %%
population_df.head()
# Out:
#    Year  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0  1990  4050055  553290  3684097   2356586    29959515   3307618
# 1  1991  4099156  570193  3788576   2383144    30470736   3387119
# 2  1992  4154014  588736  3915740   2415984    30974659   3495939
# 3  1993  4214202  599432  4065440   2456303    31274928   3613734
# 4  1994  4260229  603308  4245089   2494019    31484435   3724168
#
#    Connecticut  Delaware  District of Columbia   ...     South Dakota  \
# 0      3291967    669567                605321   ...           697101
# 1      3302895    683080                600870   ...           703669
# 2      3300712    694925                597565   ...           712801
# 3      3309175    706378                595301   ...           722159
# 4      3316121    717545                589239   ...           730790
#
#    Tennessee     Texas     Utah  Vermont  Virginia  Washington  West Virginia  \
# ...

# %% [markdown]
# ### Import number of school shootings per year csv and create DataFrame

# %%
filepath2 = '../../output/sparse_school_shootings_per_state_per_year.csv'
csv2 = pd.read_csv(filepath2)
shootings_df = pd.DataFrame(csv2)

# name year column (currently unnamed)
shootings_df = shootings_df.rename(columns={'Unnamed: 0': 'Year'})

# %%
shootings_df.head(30)
# Out:
#     Year  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0   1990        0       0        0         0           0         0
# 1   1991        0       0        0         0           1         0
# 2   1992        1       0        1         0           2         0
# 3   1993        0       0        0         0           4         0
# 4   1994        0       0        0         0           5         0
# 5   1995        0       0        0         0           2         0
# 6   1996        1       0        0         1           5         0
# 7   1997        0       1        0         1           2         0
# 8   1998        0       0        0         2           5         0
# 9   1999        0       0        0         0           1         1
# 10  2000        0       0        1         1           2         0
# 11  2001        0       0        0         0           4         0
# 12  2002        0       0        1         0           0         0
# ...

# %%
population_df.head(30)
# Out:
#     Year  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0   1990  4050055  553290  3684097   2356586    29959515   3307618
# 1   1991  4099156  570193  3788576   2383144    30470736   3387119
# 2   1992  4154014  588736  3915740   2415984    30974659   3495939
# 3   1993  4214202  599432  4065440   2456303    31274928   3613734
# 4   1994  4260229  603308  4245089   2494019    31484435   3724168
# 5   1995  4296800  604412  4432499   2535399    31696582   3826653
# 6   1996  4331102  608569  4586940   2572109    32018834   3919972
# 7   1997  4367935  612968  4736990   2601090    32486010   4018293
# 8   1998  4404701  619932  4883342   2626289    32987675   4116639
# 9   1999  4430141  624779  5023823   2651860    33499204   4226018
# 10  2000  4452173  627963  5160586   2678588    33987977   4326921
# 11  2001  4467634  633714  5273477   2691571    34479458   4425687
# 12  2002  4480089  642337  5396255   2705927    34871843   4490406
# ...

# %% [markdown]
# ### Import unemployment rate csv

# %%
filepath3 = '../../raw/economic_stats/unemployment_by_state.csv'
csv3 = pd.read_csv(filepath3)
unemployment_rate_df = pd.DataFrame(csv3)

# %%
unemployment_rate_df.head(30)
# Out:
#     State  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0    1990      6.8     7.2      5.3       6.9         5.8       5.2
# 1    1991      7.3     8.5      5.9       7.4         7.7       5.3
# 2    1992      7.6     8.9      7.5       7.1         9.3       6.0
# 3    1993      7.3     7.7      6.4       6.1         9.5       5.3
# 4    1994      6.2     7.6      6.1       5.4         8.6       4.2
# 5    1995      6.0     7.3      5.3       4.8         7.9       4.0
# 6    1996      5.2     7.6      5.6       5.3         7.3       4.2
# 7    1997      5.0     7.1      4.6       5.2         6.4       3.5
# 8    1998      4.4     6.3      4.3       5.2         5.9       3.6
# 9    1999      4.7     6.5      4.4       4.6         5.2       3.1
# 10   2000      4.6     6.4      4.0       4.3         4.9       2.8
# 11   2001      5.1     6.4      4.8       5.0         5.4       3.8
# 12   2002      5.9     7.3      6.1       5.5         6.7       5.5
# ...

# %% [markdown]
# ### Cut off population and shooting dataframes to 2015

# %%
shootings_df = shootings_df[shootings_df['Year'] != 2018]
shootings_df = shootings_df[shootings_df['Year'] != 2017]
shootings_df = shootings_df[shootings_df['Year'] != 2016]

shootings_df = shootings_df.replace(np.nan, 0)

population_df = population_df[population_df['Year'] != 2018]
population_df = population_df[population_df['Year'] != 2017]
population_df = population_df[population_df['Year'] != 2016]

population_df = population_df.replace(np.nan, 0)

# %% [markdown]
# ### Divide number of school shootings by population to get school shootings per capita

# %%
shootings_percap_df = shootings_df / population_df

# %% [markdown]
# ### Calculate correlation between a state's school shootings per capita and its unemployment rate

# %%
np.corrcoef(shootings_percap_df['Illinois'], unemployment_rate_df['Illinois'])
# Out:
# array([[ 1.        ,  0.40333739],
#        [ 0.40333739,  1.        ]])

# %%
# Check correlations between school shootings per capita and unemployment rate
for element in population_df.columns.tolist()[1:]:
    print(element, 'Pearson correlation (25 yrs): ', pearsonr(shootings_percap_df[element], unemployment_rate_df[element]))
# Out:
# Alabama Pearson correlation (25 yrs):  (0.48052633159265395, 0.012964214604823363)
# Alaska Pearson correlation (25 yrs):  (-0.030337336440447314, 0.88304022457666542)
# Arizona Pearson correlation (25 yrs):  (0.25964971286457772, 0.20021154382637354)
# Arkansas Pearson correlation (25 yrs):  (-0.30338071804532923, 0.13190510312775255)
# California Pearson correlation (25 yrs):  (0.3886248428432128, 0.049756261054039332)
# Colorado Pearson correlation (25 yrs):  (0.2629172586892074, 0.19440466733398512)
# Connecticut Pearson correlation (25 yrs):  (0.40140860759274666, 0.042101346276298621)
# Delaware Pearson correlation (25 yrs):  (0.12452808735169137, 0.54444211468636405)
# District of Columbia Pearson correlation (25 yrs):  (0.11076163995334523, 0.59012038291908064)
# Florida Pearson correlation (25 yrs):  (-0.0087096959929334229, 0.96631742415530519)
# Georgia Pearson correlation (25 yrs):  (0.076071343629587604, 0.71186808998430129)
# ...

# %% [markdown]
# # Same, but with median household income

# %% [markdown]
# ### Import median household income dataset

# %%
filepath4 = '../../raw/economic_stats/census_median_household_income.csv'
csv4 = pd.read_csv(filepath4)
mhi_df = pd.DataFrame(csv4)

# %%
mhi_df.State.max()
# Out:
# 2016

# %%
mhi_df = mhi_df[mhi_df.State != 2016]
mhi_df = mhi_df.rename(columns={'D.C.': 'District of Columbia'})

# %%
mhi_df = mhi_df.replace(np.nan, 0)
mhi_df.head(30)
# Out:
#     State  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0    1990    23357   39298    29224     22786       33290     30733
# 1    1991    24346   40612    30737     23435       33664     31499
# 2    1992    25808   41802    29358     23882       34903     32484
# 3    1993    25082   42931    30510     23039       34073     34488
# 4    1994    27196   45367    31293     25565       35331     37833
# 5    1995    25991   47954    30863     25814       37009     40706
# 6    1996    30302   52779    31637     27123       38812     40950
# 7    1997    31939   47994    32740     26162       39694     43233
# 8    1998    36266   50692    37090     27665       40934     46599
# 9    1999    36251   51396    36995     29682       43629     48177
# 10   2000    35424   52847    39783     29697       46816     48240
# 11   2001    35160   57363    42704     33339       47262     49397
# 12   2002    37603   52774    39734     32387       47437     48294
# ...

# %%
# Check correlations between school shootings per capita and unemployment rate
for element in shootings_percap_df.columns.tolist()[:-1]:
    print(element, 'Pearson correlation (25 yrs): ', pearsonr(shootings_percap_df[element], mhi_df[element]))
# Out:
# Alabama Pearson correlation (25 yrs):  (0.258710782969096, 0.20190183464894515)
# Alaska Pearson correlation (25 yrs):  (-0.14961730916110219, 0.46569410840604686)
# Arizona Pearson correlation (25 yrs):  (0.22495315598526622, 0.26921851648473616)
# Arkansas Pearson correlation (25 yrs):  (-0.063429304553010768, 0.75821107770291052)
# California Pearson correlation (25 yrs):  (-0.11202551695883464, 0.5858587302256858)
# Colorado Pearson correlation (25 yrs):  (0.3199948224271022, 0.11101619791634493)
# Connecticut Pearson correlation (25 yrs):  (0.1918810258260468, 0.3477039830130686)
# Delaware Pearson correlation (25 yrs):  (0.0039803260820664918, 0.98460369477939524)
# District of Columbia Pearson correlation (25 yrs):  (-0.21537652754177866, 0.29066573345004054)
# Florida Pearson correlation (25 yrs):  (0.22661244676245951, 0.26560869776321944)
# Georgia Pearson correlation (25 yrs):  (0.042715568770485469, 0.83586170466928689)
# ...

# %% [markdown]
# ## Same, with std. err of median household income

# %%
filepath5 = '../../raw/economic_stats/census_median_household_income_stderr.csv'
csv5 = pd.read_csv(filepath5)
mhi_se_df = pd.DataFrame(csv5)

# %%
mhi_se_df.Year.max()
# Out:
# 2016

# %%
mhi_se_df = mhi_se_df[mhi_se_df.Year != 2016]
mhi_se_df = mhi_se_df.rename(columns={'D.C.': 'District of Columbia'})

# %%
mhi_se_df = mhi_se_df.replace(np.nan, 0)

# %%
for element in shootings_percap_df.columns.tolist()[:-1]:
    print(element, 'Pearson correlation (25 yrs): ', pearsonr(shootings_percap_df[element], mhi_se_df[element]))
# Out:
# Alabama Pearson correlation (25 yrs):  (0.31417362466353749, 0.11803627045936879)
# Alaska Pearson correlation (25 yrs):  (-0.16887882502832696, 0.40953403411460187)
# Arizona Pearson correlation (25 yrs):  (0.36855449206683805, 0.063929374248337473)
# Arkansas Pearson correlation (25 yrs):  (-0.15051262252715847, 0.46299831172283112)
# California Pearson correlation (25 yrs):  (0.045811992456136645, 0.82413946348569278)
# Colorado Pearson correlation (25 yrs):  (0.30701487047499937, 0.12710947989272167)
# Connecticut Pearson correlation (25 yrs):  (0.076070921713367809, 0.71186962115637797)
# Delaware Pearson correlation (25 yrs):  (-0.13203195595305983, 0.52025823257624126)
# District of Columbia Pearson correlation (25 yrs):  (-0.15726762035115333, 0.44292393122579199)
# Florida Pearson correlation (25 yrs):  (0.47222179537790326, 0.014858321796077502)
# Georgia Pearson correlation (25 yrs):  (0.43491359549542841, 0.02639073218846617)
# ...

# %% [markdown]
# # Lets check violent crime too just in case

# %%
filepath6 = '../../raw/ucr_violent_crime_rate_by_state.csv'
csv6 = pd.read_csv('../../raw/ucr_violent_crime_rate_by_state.csv')
vc_df = pd.DataFrame(csv6)

# %%
vc_df.Year.max()
# Out:
# 2014

# %% [markdown]
# ### have to cut down other dataframes to fit, this one is a year shorter, both start at 1990

# %%
for element in shootings_percap_df.columns.tolist()[:-1]:
    print(element, 'Pearson correlation (24 yrs): ', pearsonr(shootings_percap_df[element][:-1], vc_df[element]))
# Out:
# Alabama Pearson correlation (24 yrs):  (-0.20136348331058504, 0.33444082251139151)
# Alaska Pearson correlation (24 yrs):  (0.18356829981418732, 0.37975410600063542)
# Arizona Pearson correlation (24 yrs):  (-0.18191455881111457, 0.38413607778783099)
# Arkansas Pearson correlation (24 yrs):  (-0.068116105143850067, 0.74630141381820447)
# California Pearson correlation (24 yrs):  (0.11080307287987391, 0.59799904236790691)
# Colorado Pearson correlation (24 yrs):  (-0.26318143893441714, 0.20369725726817958)
# Connecticut Pearson correlation (24 yrs):  (-0.15408229411949098, 0.46210919657648764)
# Delaware Pearson correlation (24 yrs):  (0.13799747968891082, 0.51065301293778642)
# District of Columbia Pearson correlation (24 yrs):  (0.21904974403031605, 0.29279011251716847)
# Florida Pearson correlation (24 yrs):  (-0.1312788361914406, 0.53163921979829076)
# Georgia Pearson correlation (24 yrs):  (-0.034122846484193232, 0.87136400368031586)
# ...

# %% [markdown]
# # Lets do homicide as well

# %%
filepath7 = '../../raw/additional_crime_stats/ucr_violent_crime_total.csv'
csv7 = pd.read_csv(filepath7)
homicide_df = pd.DataFrame(csv7)

# %% [markdown]
# ### For this one, since it is total violent crime rather than a rate, we will use the shootings_df, rather than the per_capita

# %%
homicide_df.Year.max()
# Out:
# 2014

# %%
for element in shootings_df.columns.tolist()[1:]:
    print(element, 'Pearson correlation (24 yrs): ', pearsonr(shootings_df[element][:-1], homicide_df[element]))
# Out:
# Alabama Pearson correlation (24 yrs):  (-0.188898309266568, 0.36582752331208679)
# Alaska Pearson correlation (24 yrs):  (0.0374456466662203, 0.85895485459391319)
# Arizona Pearson correlation (24 yrs):  (-0.057353773134906985, 0.78538261891220307)
# Arkansas Pearson correlation (24 yrs):  (-0.079916698068750389, 0.70414241925591003)
# California Pearson correlation (24 yrs):  (0.0095502073192207694, 0.96386242150591306)
# Colorado Pearson correlation (24 yrs):  (-0.11370137451939875, 0.58839616902466751)
# Connecticut Pearson correlation (24 yrs):  (-0.15737639898275957, 0.45247385032628373)
# Delaware Pearson correlation (24 yrs):  (0.23979242106977225, 0.24828643302258729)
# District of Columbia Pearson correlation (24 yrs):  (0.16628767630413455, 0.42694737069364819)
# Florida Pearson correlation (24 yrs):  (-0.24759385080342877, 0.23275961680928139)
# Georgia Pearson correlation (24 yrs):  (-0.13798538010668832, 0.51069044004698971)
# ...
